# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [raw]
# SDSS CASJOBS SQL Query:
#
# SELECT
#   s.ra,s.dec,
#   s.psfmag_r as r
#
# FROM
#   star as s
#
# WHERE
#   s.psfmag_g-r < 0.4
#   AND r > 20.0
#   AND r <= 22.00
#   AND ((s.flags_r & 0x10000000) != 0)
#   AND ((s.flags_r & 0x8100000c00a4) = 0)
#   AND (((s.flags_r & 0x400000000000) = 0) or (s.psfmagerr_r <= 0.2))
#   AND (((s.flags_r & 0x100000000000) = 0) or (s.flags_r & 0x1000) = 0)
#
# INTO
#   mydb.fieldA

# %%
x = fits.open("fieldA_dbordenave_1.fit")
ra=x[1].data.field('ra')
dec=x[1].data.field('dec')
r=x[1].data.field('r')
x.close()

# %%
#masks
b_mask=np.where((r>20.00)&(r<=20.66))
g_mask=np.where((r>20.66)&(r<=21.33))
r_mask=np.where((r>21.33)&(r<=22.00))

#bins
ra_range=np.ceil(ra.max()-ra.min())             #rounded up number of degrees for 
dec_range=np.ceil(dec.max()-dec.min())          # RA and DEC 

ra_bins=ra_range*2.0                                      #Approximate 0.5 X 0.5 degree binning
dec_bins=dec_range*2.0

#binning stars with 'r,g,b' masking
B_stars,xe,xy=np.histogram2d(ra[b_mask],dec[b_mask],bins=(ra_bins,dec_bins))
G_stars,xe,xy=np.histogram2d(ra[g_mask],dec[g_mask],bins=(ra_bins,dec_bins))
R_stars,xe,xy=np.histogram2d(ra[r_mask],dec[r_mask],bins=(ra_bins,dec_bins))

# %%
# Out:
# 0.0

# %%
#Setting range of data
range_b=np.where(B_stars<25)
range_g=np.where(G_stars<25)
range_r=np.where(R_stars<25)
B_stars[range_b]=0.001
G_stars[range_g]=0.001
R_stars[range_r]=0.001

# %%
rgb_frame=np.dstack((R_stars.T/R_stars.max(),G_stars.T/G_stars.max(),B_stars.T/B_stars.max()))
ext=[ra.min(),ra.max(),dec.min(),dec.max()]
with plt.style.context(('dark_background')):
    fig,ax=plt.subplots()
    ax.set_xlim(ra.max(),ra.min())

    ax.set_xlabel('RA')
    ax.set_ylabel('Dec')

    ax.imshow(rgb_frame,extent=ext,aspect='auto', origin='lower')
    fig.set_size_inches(10,5)
    fig.savefig('field_of_streams.png',dpi=250)

# %%
from matplotlib.colors import LogNorm
plt.matshow(R_stars.T,origin='lower',norm=LogNorm(vmin=20.0, vmax=R_stars.max()))

# %%
np.unique(rgb_frame)
# Out:
# array([ 0.        ,  0.00131406,  0.00162602,  0.00191939,  0.00262812,
#         0.00325203,  0.00383877,  0.00394218,  0.00487805,  0.00525624,
#         0.00575816,  0.00650407,  0.0065703 ,  0.00767754,  0.00788436,
#         0.00813008,  0.00919842,  0.00959693,  0.0097561 ,  0.01051248,
#         0.01138211,  0.01151631,  0.01182654,  0.01300813,  0.0131406 ,
#         0.11382114,  0.11432326,  0.11516315,  0.11544715,  0.11563732,
#         0.11695138,  0.11707317,  0.11708253,  0.11826544,  0.11869919,
#         0.11900192,  0.1195795 ,  0.1203252 ,  0.12089356,  0.12092131,
#         0.12195122,  0.12220762,  0.12284069,  0.12352168,  0.12357724,
#         0.12476008,  0.12483574,  0.12520325,  0.1261498 ,  0.12667946,
#         0.12682927,  0.12746386,  0.12845528,  0.12859885,  0.12877792,
#         0.1300813 ,  0.13009198,  0.13051823,  0.13140604,  0.13170732,
#         0.13243762,  0.13272011,  0.13333333,  0.13403417,  0.13435701,
#         0.13495935,  0.13534823,  0.13627639,  0.13658537,  0.13666229,
#         0.13797635,  0.13819578,  0.13821138,  0.1398374 ,  0.14011516,
#         0.14060447,  0.14146341,  0.14191853,  0.14203455,  0.14308943,
#         0.14323259,  0.14395393,  0.14454665,  0.14471545,  0.14586071,
#         0.14587332,  0.14634146,  0.14779271,  0.14796748,  0.14848883,
#         0.1495935 ,  0.14971209,  0.15121951,  0.15163148,  0.15284553,
#         0.15355086,  0.15374507,  0.15447154,  0.15505913,  0.15547025,
#         0.15738964,  0.15768725,  0.15772358,  0.15930902,  0.15934959,
#         0.16097561,  0.16122841,  0.16260163,  0.1629435 ,  0.16314779,
#         0.16422764,  0.16506718,  0.16557162,  0.16585366,  0.16688568,
#         0.16698656,  0.16747967,  0.16890595,  0.16910569,  0.17082534,
#         0.17082786,  0.17235772,  0.17274472,  0.17398374,  0.17466411,
#         0.17560976,  0.17658349,  0.17723577,  0.17850288,  0.17886179,
#         0.18002628,  0.18042226,  0.1804878 ,  0.18211382,  0.18234165,
#         0.18373984,  0.18426104,  0.18536585,  0.18618042,  0.18659658,
#         0.18699187,  0.18861789,  0.19001919,  0.19193858,  0.19316689,
#         0.19385797,  0.19769674,  0.19837398,  0.20105125,  0.20153551,
#         0.20162602,  0.20487805,  0.20729367,  0.20921305,  0.21138211,
#         0.21287779,  0.21305182,  0.21813403,  0.21880998,  0.22072937,
#         0.22439024,  0.22764228,  0.2303263 ,  0.23089431,  0.23608445,
#         0.23800384,  0.23992322,  0.24184261,  0.243762  ,  0.24552846,
#         0.24704336,  0.24760077,  0.24952015,  0.25365854,  0.25691057,
#         0.27317073,  0.27447217,  0.28943089,  0.29174664,  0.29960578,
#         0.30134357,  0.30518234,  0.32245681,  0.3243762 ,  0.32821497,
#         0.35316699,  0.36276392,  0.38579655,  0.42444152,  0.4452975 ,
#         0.44913628,  0.5950096 ,  1.        ])

# %%
print np.sort(R_stars.flatten())[-5:]
print np.sort(G_stars.flatten())[-5:]
print np.sort(B_stars.flatten())[-5:]
# Out:
# [ 158.  158.  168.  178.  615.]
# [ 166.  188.  228.  323.  761.]
# [ 201.  232.  234.  310.  521.]
